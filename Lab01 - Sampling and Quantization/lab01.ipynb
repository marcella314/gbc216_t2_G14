# %% [markdown]
# **Processamento Digital de Imagens**
#
# Prática de Amostragem e Quantização
#
# Instruções:
# Utilize python e a biblioteca OpenCV para abertura das imagens.

# %% [markdown]
# Grupo:
# Integrantes

# %% [markdown]
# 1)	Utilizando imagem relogio.tif e faça uma reamostragem de seus pixels para 300, 150 e 72 dpi. Sabe-se que a imagem original possui 1250 dpi. Fazer os cálculos por meio do seu algortimo. Não usar o opencv para a conversão

# %%
# type your code here
# Python code to read image
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread("relogio.tif", cv2.IMREAD_GRAYSCALE)

print('Tamanho da imagem : ',img.shape)
# convertendo para 300dpi

linhas = img.shape[0]
colunas = img.shape[1]

dpi_original = 1250
dpi_desejado = 72 #trocar entre 300, 150 e 72 para testar 

fator = dpi_original/dpi_desejado 

nova_linha = int(linhas/fator)
nova_coluna = int(colunas/fator)

nova_imagem = np.zeros((int(linhas/fator), int(colunas/fator)), dtype=int)

for i in range(nova_linha):
    for j in range(nova_coluna):
        nova_imagem[i][j] = img[i*int(fator)][j*int(fator)]

plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.subplot(1, 2, 2)
plt.imshow(nova_imagem, cmap='gray', vmin=0, vmax=255)
# Out:
# Tamanho da imagem :  (3692, 2812)

# %% [markdown]
# 2)	Utilizando a imagem ctskull-256.tif, refaça a quantização de seus pixels utilizando de 7 a 1 bit(s) por pixel.  Fazer os cálculos por meio do seu algortimo. Não usar o opencv para a conversão

# %%
img2 = cv2.imread("CTSKULL-256.tif", cv2.IMREAD_GRAYSCALE)

linhas2 = img2.shape[0]
colunas2 = img2.shape[1]

bit = 1 #faça variar de 1 até 7 para testar

fator2 = 2**(8-bit) 

nova_imagem2 = np.zeros((linhas2, colunas2), dtype=int)

for i in range(linhas2):
    for j in range(colunas2):
            nova_imagem2[i][j] = int(img2[i][j]/fator2)

plt.subplot(1, 2, 1)
plt.imshow(img2, cmap='gray', vmin=0, vmax=255)
plt.subplot(1, 2, 2)
plt.imshow(nova_imagem2, cmap='gray', vmin=0, vmax=((2**(bit)-1)))
